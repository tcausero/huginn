# %%
import sys
sys.path.append("..")
import time
from huginn.huginn import Huginn
# Out:
# /Users/thomascausero/anaconda3/envs/capstone36/lib/python3.6/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning:
#
# `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.

# %%
cl = Huginn('Apple')
# Out:
# [{'mid': '/m/0k8z', 'title': 'Apple', 'type': 'Technology company'}, {'mid': '/m/014j1m', 'title': 'Apple', 'type': 'Fruit'}, {'mid': '/g/11c1s04k8p', 'title': 'AirPods', 'type': 'Topic'}, {'mid': '/m/027lnzs', 'title': 'iPhone', 'type': 'Mobile phone'}, {'mid': '/m/01qd72', 'title': 'Apples', 'type': 'Plants'}]
# Enter the mid you are interested in: /m/0k8z

# %%
cl.plot_interest()

# %%
cl.get_anomalies(k=1)
# Out:
# DatetimeIndex(['2007-09-01', '2008-01-01', '2008-06-01', '2010-01-01',
#                '2010-07-01', '2011-10-01', '2012-09-01', '2013-09-01',
#                '2014-09-01', '2015-03-01'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
cl.plot_interest_with_anomalies()
# Out:
#         If you are not happy with these anomalies, you can call the method 'get_anomalies' and
#         specify the function to get anomalies:
#         - method = 'constant' with parameter k (set to 1 by default)
#         - method = 'rolling' with parameters lookback_mean, lookback_std and k (set to 1, 10, 1 by default)
#         - method = 'ewm' with parameters halflife_mean, halflife_std and k(set to 1,10,1 by default) [default method]

# %%
num_links = 10

# %%
t1 = time.time()
cl.get_info(num_links = num_links)
print(str(int(time.time()-t1)) + 's to compute')
# Out:
# anomaly n°1: 9 articles were found and 100% could have been scrapped
# anomaly n°2: 9 articles were found and 100% could have been scrapped
# anomaly n°3: 9 articles were found and 100% could have been scrapped
# anomaly n°4: 7 articles were found and 100% could have been scrapped
# anomaly n°5: 10 articles were found and 100% could have been scrapped
# anomaly n°6: 9 articles were found and 100% could have been scrapped
# anomaly n°7: 10 articles were found and 100% could have been scrapped
# anomaly n°8: 6 articles were found and 100% could have been scrapped
# anomaly n°9: 10 articles were found and 100% could have been scrapped
# anomaly n°10: 9 articles were found and 100% could have been scrapped
# 31s to compute
