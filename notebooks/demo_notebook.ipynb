# %%
import sys
sys.path.append("..")
import time
from client.demo_console import demo_console

# %%
cl = demo_console()
# Out:
# keyword: Steve Jobs
# [{'mid': '/m/06y3r', 'title': 'Steve Jobs', 'type': 'American business magnate'}, {'mid': '/m/012hyvv1', 'title': 'Steve Jobs', 'type': 'Film'}, {'mid': '/m/0h3xrzh', 'title': 'Steve Jobs', 'type': 'Book by Walter Isaacson'}, {'mid': '/m/0j7j4ls', 'title': 'Jobs', 'type': 'Film'}, {'mid': '/m/051dqy7', 'title': 'Steve Jobs', 'type': 'Book by Jeffrey S. Young'}]
# Enter the mid you are interested in: /m/06y3r

# %%
cl.plot_interest()

# %%
cl.get_anomalies()
# Out:
# DatetimeIndex(['2007-09-01', '2008-01-01', '2008-06-01', '2009-01-01',
#                '2009-06-01', '2010-06-01', '2011-01-01', '2011-02-01',
#                '2011-08-01', '2011-10-01'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
cl.plot_interest_with_anomalies()
# Out:
#         If you are not happy with these anomalies, you can call the method 'get_anomalies' and
#         specify the function to get anomalies:
#         - method = 'constant' with parameter k (set to 1 by default)
#         - method = 'rolling' with parameters lookback_mean, lookback_std and k (set to 1, 10, 1 by default)
#         - method = 'ewm' with parameters halflife_mean, halflife_std and k(set to 1,10,1 by default) [default method]

# %%
num_links = 10
k = 2

# %%
t1 = time.time()
cl.get_summary(num_links = num_links, k = k)
print(str(int(time.time()-t1)) + 's to compute')
# Out:
# Problem with the following url: https://bits.blogs.nytimes.com/2007/08/05/the-trial-of-fake-steve-jobs/
# Problem with the following url: https://bits.blogs.nytimes.com/2008/01/15/the-passion-of-steve-jobs/
# Problem with the following url: https://pogue.blogs.nytimes.com/2008/01/14/steve-jobs-keynote-fun-and-games/
# Problem with the following url: https://bits.blogs.nytimes.com/2008/01/15/steve-jobs-again-the-master-marketer/
# Problem with the following url: https://bits.blogs.nytimes.com/2008/06/09/eight-questions-for-steve-jobs/
# Problem with the following url: https://bits.blogs.nytimes.com/2008/06/02/will-steve-jobs-set-me-free/
# Problem with the following url: https://bits.blogs.nytimes.com/2008/06/09/live-from-sf-apple-ceo-steve-jobs-unveils-new-products/
# Problem with the following url: https://bits.blogs.nytimes.com/2008/06/09/blogs/09bits-live-fro1095.html
# Problem with the following url: https://bits.blogs.nytimes.com/2008/05/28/slow-fade-bill-and-steve-at-the-d-conference/
# Problem with the following url: https://executivesuite.blogs.nytimes.com/2009/06/23/blogs/23executivesuite-steve-jo671.html
# Problem with the following url: https://well.blogs.nytimes.com/2009/06/24/35420-reasons-for-steve-jobs-to-talk/
# Problem with the following url: https://well.blogs.nytimes.com/2009/06/24/blogs/24well-35420-re807.html
# Problem with the following url: https://bits.blogs.nytimes.com/2009/06/24/steve-jobs-and-apple-here-we-go-again/
# Problem with the following url: https://dealbook.nytimes.com/2010/06/11/another-view-how-to-improve-corporate-governance/
# Problem with the following url: https://bits.blogs.nytimes.com/2010/06/08/iphone-4-thoughts-from-the-tech-blogs/
# Problem with the following url: https://dealbook.nytimes.com/2010/06/03/file-sharing-pioneers-now-selling-music/
# Problem with the following url: https://bits.blogs.nytimes.com/2010/05/24/as-apples-conference-approaches-can-jobs-wow-attendees/
# Problem with the following url: https://bits.blogs.nytimes.com/2010/05/17/with-a-kindle-hiring-spree-amazon-gears-up-for-battle-with-apple/
# Problem with the following url: https://bits.blogs.nytimes.com/2010/05/13/next-round-in-the-adobe-apple-fight/
# Problem with the following url: https://bits.blogs.nytimes.com/2010/05/05/has-apple-lost-its-cool/
# Problem with the following url: https://opinionator.blogs.nytimes.com/2010/06/01/is-steve-jobs-big-brother/
# Problem with the following url: https://kristof.blogs.nytimes.com/2010/06/30/steve-jobs-statement-on-conflict-minerals/
# Problem with the following url: https://dealbook.nytimes.com/2011/01/06/morning-take-out-156/
# Problem with the following url: https://dealbook.nytimes.com/2010/12/08/charity-guessing-game-who-will-join-gates-and-buffett/
# Problem with the following url: https://thequad.blogs.nytimes.com/2011/01/01/pitt-fires-its-new-coach/
# Problem with the following url: https://bits.blogs.nytimes.com/2011/02/09/a-23-year-old-steve-jobs-on-tv/
# Problem with the following url: https://bits.blogs.nytimes.com/2011/02/18/the-mystery-of-obamas-dinner-with-tech-execs/
# Problem with the following url: https://bits.blogs.nytimes.com/2011/02/17/top-silicon-valley-execs-to-meet-with-obama/
# Problem with the following url: https://bits.blogs.nytimes.com/2011/02/04/apple-patents-a-stylus-to-reach-students/
# Problem with the following url: https://pogue.blogs.nytimes.com/2011/08/25/steve-jobs-reshaped-industries/
# Problem with the following url: https://economix.blogs.nytimes.com/2011/08/26/podcast-bernanke-the-budget-and-steve-jobs/
# Problem with the following url: https://dealbook.nytimes.com/2011/08/29/the-mystery-of-steve-jobss-public-giving/
# Problem with the following url: https://bits.blogs.nytimes.com/2011/08/15/steve-jobs-biography-set-for-november-release/
# Problem with the following url: https://mediadecoder.blogs.nytimes.com/2011/08/25/on-madison-avenue-talk-of-jobss-legacy/
# Problem with the following url: https://well.blogs.nytimes.com/2011/10/31/steve-jobss-cancer-choices/
# Problem with the following url: https://bits.blogs.nytimes.com/2011/10/23/steve-jobss-search-for-his-father/
# Problem with the following url: https://bits.blogs.nytimes.com/2011/10/21/steve-jobs-biography-a-scorecard-of-put-downs/
# Problem with the following url: https://bits.blogs.nytimes.com/2011/10/17/a-star-studded-memorial-to-steve-jobs/
# Problem with the following url: https://bits.blogs.nytimes.com/2011/10/23/apple-posts-video-from-steve-jobs-tribute/
# Problem with the following url: https://wheels.blogs.nytimes.com/2011/10/27/how-steve-jobs-legally-drove-without-a-license-plate/
# Problem with the following url: https://bits.blogs.nytimes.com/2011/10/14/memorial-service-for-steve-jobs-planned-at-stanford/
# Problem with the following url: https://bits.blogs.nytimes.com/2011/10/17/emotion-music-and-humor-at-steve-jobs-memorial/
# Problem with the following url: https://india.blogs.nytimes.com/2011/10/10/where-is-indias-steve-jobs/
# 28s to compute

# %%
print(dir(cl))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'anomalies', 'check_got_anomalies', 'get_anomalies', 'get_summaries', 'get_summary', 'get_title_text', 'interest', 'mid', 'name', 'plot_interest', 'plot_interest_with_anomalies', 'summaries', 'summary', 'text', 'title']

# %%
cl.summary
# Out:
# {Timestamp('2007-09-01 00:00:00'): 'I\'ve been sort of waiting for this call for months." Lyons writes and edits technology articles for Forbes and is the author of two works of fiction, most recently a 1998 novel, "Dog Days." In October, Da Capo Press will publish his satirical novel written in the voice of the Fake Steve character, "Options: The Secret Life of Steve Jobs, a Parody." Unlike the off-the-cuff ramblings on his blog, "Options" is a well-plotted satire that imagines Apple\'s chief executive grappling with his real-life stock option backdating troubles and getting help, and bad advice, from friends like Larry Ellison, Bono and Al Gore.',
#  Timestamp('2008-01-01 00:00:00'): '“The commission is very much in favor of solutions that would allow consumers to buy off the iTunes online store without restrictions, but it is aware that some record companies, publishers and collecting societies still apply licensing practices which can make it difficult for iTunes to operate stores accessible for a European consumer anywhere in the E.U.,” the commission said in a statement..',
#  Timestamp('2008-06-01 00:00:00'): 'He forced Pixar employees to give up equity in return for his continued patronage at a particularly dire moment in 1991; he pushed for a public offering at another moment \x97 the mid-’90s, in the first flush of Internet mania \x97 when Pixar had scant revenues and no profits; and he craftily outmaneuvered Michael Eisner of Disney over “Toy Story 2,” which was originally conceived as a straight-to-video offering..',
#  Timestamp('2009-01-01 00:00:00'): 'Jobs sought to calm speculation about his withdrawal from his regular keynote speech at the annual Macworld conference by acknowledging he had a “hormone imbalance.” “The letter last week pretty much tried to reassure people that his health condition was extremely minor, but obviously it is more serious than first thought,” Ryan Jacob, founder of the Jacob Internet Fund, which owns a stake in Apple and is based in Los Angeles, said.',
#  Timestamp('2009-06-01 00:00:00'): 'Jobs reportedly had his transplant, the median waiting time varies from 3.8 months at Methodist Hospital in Memphis to 17.2 months at Vanderbilt University Medical Center in Nashville, according to a transplant registry operated by Arbor Research Collaborative for Health and the University of Michigan...',
#  Timestamp('2010-06-01 00:00:00'): 'Jobs helped create “the best desktop computer, the best portable music device, the best smartphone and also now the best tablet,” said Steve Perlman, a serial entrepreneur who was an executive at both Apple and Microsoft and is now the chief executive of OnLive, an online gaming company.',
#  Timestamp('2011-01-01 00:00:00'): ' “I was with Tim Cook last week in New York and I walked away from that thinking, ‘This guy is more in charge and more in control of Apple than I think people understand,’\xa0” said Tim Bajarin, an analyst with Creative Strategies who has followed Apple for nearly three decades.',
#  Timestamp('2011-02-01 00:00:00'): 'But these are not the kind of breakthroughs that market research, where you are asking people’s opinions, really help you make.” Regis McKenna, a Silicon Valley investor and marketing consultant, said employees at Apple stores provide the company with a powerful window into user habits and needs, even if it is not conventional market research.',
#  Timestamp('2011-08-01 00:00:00'): 'Have we forgotten already that Jobs virtually invented the personal computer, with the introduction of the Apple II, when he was barely 21? That a few years later he saved Apple from near-disaster by creating the Macintosh — the first commercially successful machine with a mouse and windows, and all the other features we associate with modern computing? That the NeXT operating system was critical to the next generation of Macintosh computers after Jobs returned from a 12-year exile in 1997? And, yes, then came the iPod, the iPhone and iPad — all of them so elegant in their look and feel that they became more than devices.',
#  Timestamp('2011-10-01 00:00:00'): 'His philosophy of aesthetics reminds me of a quote that went something like this: “Fashion is what seems beautiful now but looks ugly later; art can be ugly at first but it becomes beautiful later.” Steve always aspired to make beautiful later.'}
