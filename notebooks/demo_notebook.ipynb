# %%
import sys
sys.path.append("..")
import time
from client.demo_console import demo_console

# %%
cl = demo_console()
# Out:
# keyword: Apple
# [{'mid': '/m/0k8z', 'title': 'Apple', 'type': 'Technology company'}, {'mid': '/m/014j1m', 'title': 'Apple', 'type': 'Fruit'}, {'mid': '/g/11c1s04k8p', 'title': 'AirPods', 'type': 'Topic'}, {'mid': '/m/027lnzs', 'title': 'iPhone', 'type': 'Mobile phone'}, {'mid': '/m/01qd72', 'title': 'Apples', 'type': 'Plants'}]
# Enter the mid you are interested in: /m/0k8z

# %%
cl.plot_interest()

# %%
cl.get_anomalies()
# Out:
# DatetimeIndex(['2007-09-01', '2008-01-01', '2008-06-01', '2010-01-01',
#                '2010-07-01', '2011-10-01', '2012-09-01', '2013-09-01',
#                '2014-09-01', '2015-03-01'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
cl.plot_interest_with_anomalies()
# Out:
#         If you are not happy with these anomalies, you can call the method 'get_anomalies' and
#         specify the function to get anomalies:
#         - method = 'constant' with parameter k (set to 1 by default)
#         - method = 'rolling' with parameters lookback_mean, lookback_std and k (set to 1, 10, 1 by default)
#         - method = 'ewm' with parameters halflife_mean, halflife_std and k(set to 1,10,1 by default) [default method]

# %%
num_links = 1
k = 1

# %%
t1 = time.time()
cl.get_summary(num_links = num_links, k = k)
print(str(int(time.time()-t1)) + 's to compute')
# Out:
# Problem with the following url: https://gadgetwise.blogs.nytimes.com/2010/07/27/apple-brings-magic-multitouch-to-the-computer/
# Problem with the following url: https://bits.blogs.nytimes.com/2011/10/27/whats-really-next-for-apple-in-television/
# 13s to compute

# %%
print(dir(cl))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'anomalies', 'check_got_anomalies', 'get_anomalies', 'get_image', 'get_summaries', 'get_summary', 'get_title_text', 'interest', 'mid', 'name', 'plot_interest', 'plot_interest_with_anomalies', 'summaries', 'summary', 'text', 'title']

# %%
cl.summary
# Out:
# {Timestamp('2007-09-01 00:00:00'): '(Apple’s market share in music players has not suffered a similar fate, however.)On Wednesday, Apple executives insisted that the price cut had been planned long ago and that the strategy had been conceived in part to keep the iPhone’s pricing in line with its new iPod Touch, a music player that looks like the iPhone but lacks the phone-calling ability...',
#  Timestamp('2008-01-01 00:00:00'): 'Oppenheimer of Apple said that sales of the iPod in the United States were little changed in the quarter, although iPod sales abroad were quite strong...',
#  Timestamp('2008-06-01 00:00:00'): 'Jobs, chief executive of Apple, introduced a new cheaper iPhone model on Monday that navigates the Internet more quickly, expanded its distribution overseas and displayed a range of new applications and services in order to establish Apple as a major player in the cellphone industry...',
# ...

# %%
cl.get_image()
# Out:
# {Timestamp('2007-09-01 00:00:00'): [['https://static01.nyt.com/images/2007/09/06/business/06apple-600.jpg?quality=75&auto=webp&disable=upscale',
#    'https://static01.nyt.com/images/2007/09/06/business/06apple.1-650.jpg?quality=75&auto=webp&disable=upscale',
#    'https://static01.nyt.com/images/2007/09/05/technology/06ipodtouch.1.190.jpg?quality=75&auto=webp&disable=upscale']],
#  Timestamp('2008-01-01 00:00:00'): [['https://static01.nyt.com/images/2008/01/23/business/23apple.span.jpg?quality=75&auto=webp&disable=upscale']],
#  Timestamp('2008-06-01 00:00:00'): [['https://static01.nyt.com/images/2008/06/10/business/10apple-span-600.jpg?quality=75&auto=webp&disable=upscale',
#    'https://static01.nyt.com/images/2008/06/10/business/10apple-inline1-500.jpg?quality=75&auto=webp&disable=upscale',
#    'https://static01.nyt.com/images/2008/06/09/technology/JobsIPhonePackage.312x176.fr.jpg']],
#  Timestamp('2010-01-01 00:00:00'): [[]],
# ...
