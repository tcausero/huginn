# %%
import sys
sys.path.append("..")
import time
from huginn.huginn import Huginn

# %%
cl = Huginn('Apple')
# Out:
# [{'mid': '/m/0k8z', 'title': 'Apple', 'type': 'Technology company'}, {'mid': '/m/014j1m', 'title': 'Apple', 'type': 'Fruit'}, {'mid': '/g/11c1s04k8p', 'title': 'AirPods', 'type': 'Topic'}, {'mid': '/m/027lnzs', 'title': 'iPhone', 'type': 'Mobile phone'}, {'mid': '/m/01qd72', 'title': 'Apples', 'type': 'Plants'}]
# Enter the mid you are interested in: /m/0k8z

# %%
cl.get_anomalies(k=2)
# Out:
# DatetimeIndex(['2007-09-01', '2008-06-01', '2010-01-01', '2010-07-01',
#                '2011-10-01', '2012-09-01', '2014-09-01'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
cl.plot_interest_with_anomalies()
# Out:
#     If you are not happy with these anomalies, you can call the method 'get_anomalies' and
#     specify the function to get anomalies:
#     - method = 'constant' with parameter k (set to 1 by default)
#     - method = 'rolling' with parameters lookback_mean, lookback_std and k (set to 1, 10, 1 by default)
#     - method = 'ewm' with parameters halflife_mean, halflife_std and k(set to 1,10,1 by default) [default method]

# %%
t1 = time.time()
cl.get_info()
print(str(int(time.time()-t1)) + 's to compute')
# Out:
# anomaly n°1: 9 articles were found and 100% were retrieved
# anomaly n°2: 8 articles were found and 100% were retrieved
# anomaly n°3: 7 articles were found and 100% were retrieved
# anomaly n°4: 10 articles were found and 100% were retrieved
# anomaly n°5: 9 articles were found and 100% were retrieved
# anomaly n°6: 10 articles were found and 100% were retrieved
# anomaly n°7: 10 articles were found and 100% were retrieved
# 17s to compute

# %%
cl.model_lda(n_components=2)

# %%
cl.get_summary(mode="summary", max_length = 100)
# Out:
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# {'09-2007': {1: "Apple cuts price of its 8-gigabyte iPhone by $200, to $399. Apple also introduces a new digital music player modeled after its iPhone. Apple struck a wireless music distribution deal with the Starbucks coffee chain. Apple's stock fell more than 5 percent, closing at $136.76.",
#   0: "Averill Farm is high in the rolling Litchfield County hills outside Washington Depot. George Washington didn't sleep here, but he is said to have partied at the original Averill farmhouse. Phoebe DeVos-Cole: “I love to pick apples, and I love to eat them”"},
#  '06-2008': {1: 'Apple to begin selling iPhone in 70 countries this summer. New iPhone 3G will sell for $199 for the 8-gigabyte model and $299 for a 16-gigs model. Phone will run on so-called 3G wireless networks that allow much faster Internet connections. Apple has sold six million phones globally since its introduction.',
#   0: "Bob Greene: Windows has become an obese monolith built on an ancient frame. He says the best solution to the multiple woes of Windows is starting over. Greene: Microsoft should take heart from Apple's willingness to brave the wrath of its users. He asks: Will Windows 7 be a top-to-bottom rewrite?"},
#  '01-2010': {1: 'Many women say the name evokes awkward associations with feminine hygiene products. Two other high-tech companies already market products called iPad and are laying claim to the trademark. Fujitsu, the Japanese technology firm, may not be quite so eager to forgive and forget. There are a few similarities between Wednesday’s Apple announcement and the blockbuster movie “Avatar”',
#   0: "Apple's A4 chip is crucial to the iPad's speed, reliability and 10-hour battery life. Chip industry experts have yet to put the iPad through their customary rigorous tests. Apple bought its way into the chip business in 2008, acquiring the 150-employee start-up PA Semi."},
#  '07-2010': {1: 'Apple announced the Magic Trackpad on Tuesday. It is similar to a laptop trackpad and acts as a replacement for a traditional mouse. It will also bring multitouch capabilities to some applications on a Mac computer. Apple also announced an update to its Mac Pro product line and the desktop iMac.',
#   0: 'iFixit posted a detailed look at the guts of Apple’s new Magic Trackpad. In its teardown of the Trackpad, iFixit found that it consists of “nine difficult-to-disassemble pieces” The Web site notes that dismantling the device is not for the faint of heart.'},
#  '10-2011': {0: "Apple co-founder Steven P. Jobs was talking about Siri, the company's new artificial intelligent software. Apple engineers and designers have been struggling for years to find a new interface for the television. Alternative remote ideas floated by Apple included a wireless keyboard and mouse, or using an iPod, iPhone or iPad.",
#   1: 'Walter Isaacson\'s "Steve Jobs" is a biography of record. It is a strange book to read so soon after its subject’s death. Mr. Isaacson knows how to explicate and celebrate genius: revered, long-dead genius. But he wrote ‘Steve Jobs’ as its subject was mortally ill, and that is a more painful challenge.'},
#  '09-2012': {1: 'Timothy D. Cook said he was “extremely sorry” for the anguish caused. He suggested that customers try alternatives to Apple’s maps. In previous versions of iOS, the Maps app was made by Apple and powered by Google. Google, with its Android software for phones, has come to be more of a competitor to Apple.',
#   0: 'Apple’s stumble fits in with its pattern of bungling services that rely heavily on the Internet. Apple has a reputation for obsessive attention to detail in its hardware and software products. But it has stubbed its toe again and again when it comes to releasing reliable, well-designed Internet services.'},
#  '09-2014': {0: 'Apple responds to complaints that its new iPhone 6 Plus is permanently bending. The company says it performs “rigorous tests throughout the entire development cycle.” Apple says it sold more than 10 million iPhone 6 and 6 Plus smartphones over the first three days of release.',
#   1: 'New Apple tool checks iPhones for ‘Kill Switch’ Security. Starting next summer, a new law will require every smartphone sold in California to include a so-called kill switch. With Activation Lock turned on, the device could be unusable without the Apple username and password of the owner.'}}
