# %%
import sys
sys.path.append("..")
from client.demo_console import demo_console

# %%
cl = demo_console()
# Out:
# keyword: Apple
# [{'mid': '/m/0k8z', 'title': 'Apple', 'type': 'Technology company'}, {'mid': '/m/014j1m', 'title': 'Apple', 'type': 'Fruit'}, {'mid': '/g/11c1s04k8p', 'title': 'AirPods', 'type': 'Topic'}, {'mid': '/m/027lnzs', 'title': 'iPhone', 'type': 'Mobile phone'}, {'mid': '/m/01qd72', 'title': 'Apples', 'type': 'Plants'}]
# Enter the mid you are interested in: /m/0k8z

# %%
#list of attributes and method
print(dir(cl))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'check_got_anomalies', 'get_anomalies', 'get_summaries', 'get_summary', 'get_text', 'get_title', 'interest', 'mid', 'name', 'plot_interest', 'plot_interest_with_anomalies']

# %%
cl.plot_interest()

# %%
help(cl.get_anomalies)
# Out:
# Help on method get_anomalies in module client.client:
#
# get_anomalies(method='ewm', **kwargs) method of client.client.Client instance
#     Get anomalies under method assumption (by default ewm)
#
#     :argument method: ewm, rollig or constant
#     :argument **kwargs: if ewm halflife_mean, halflife_std, k (set to 1, 10 and 1 by default)
#                         if rolling lookback_mean, lookback_std, k (set to 1, 10 and 1 by default)
#                         if constant k (set to 1 by default)
#
#     :returns the anomalies as a DateIndex

# %%
cl.get_anomalies()
# Out:
# DatetimeIndex(['2007-09-01', '2008-01-01', '2008-06-01', '2010-01-01',
#                '2010-07-01', '2011-10-01', '2012-09-01', '2013-09-01',
#                '2014-09-01', '2015-03-01'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
print(dir(cl))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'anomalies', 'check_got_anomalies', 'get_anomalies', 'get_summaries', 'get_summary', 'get_text', 'get_title', 'interest', 'mid', 'name', 'plot_interest', 'plot_interest_with_anomalies']

# %%
cl.plot_interest_with_anomalies()
# Out:
#         If you are not happy with these anomalies, you can call the method 'get_anomalies' and
#         specify the function to get anomalies:
#         - method = 'constant' with parameter k (set to 1 by default)
#         - method = 'rolling' with parameters lookback_mean, lookback_std and k (set to 1, 10, 1 by default)
#         - method = 'ewm' with parameters halflife_mean, halflife_std and k(set to 1,10,1 by default) [default method]

# %%
help(cl.get_text)
# Out:
# Help on method get_text in module client.client:
#
# get_text(num_links=1) method of client.client.Client instance
#     Get most relevant texts about the entity during the anomaly dates
#
#     :argument num_links: number of relevant articles to consider for each anomaly date
#
#     :returns a dictionnary with anomaly dates as index and list of article texts as values

# %%
cl.get_text() #num_links = 1 by default
# Out:
# Problem with the following url: https://artsbeat.blogs.nytimes.com/2008/06/13/bonnaroo-exclamation-point-rock/
# Problem with the following url: https://artsbeat.blogs.nytimes.com/2010/11/29/critics-picks-video-point-blank/
# Problem with the following url: https://atwar.blogs.nytimes.com/2011/07/07/opening-doors-at-west-point/
# Problem with the following url: https://fifthdown.blogs.nytimes.com/2011/11/24/fun-with-point-differential-packers-lead-again/
# Problem with the following url: https://offthedribble.blogs.nytimes.com/2013/01/16/keeping-score-magic-pay-less-attention-to-the-3-point-line/
# ...

# %%
cl.get_title(num_links = 2)
# Out:
# ---------------------------------------------------------------------------
# NytApiError                               Traceback (most recent call last)
# <ipython-input-11-661a89a6aaba> in <module>
# ----> 1 cl.get_title(num_links = 2)
#
# ~/Documents/columbia_data_science/capstone/Capstone_KYC/client/client.py in get_title(self, num_links)
#      79         """
#      80         self.check_got_anomalies()
# ---> 81         self.title = get_articles_title_all_dates(self.name, self.anomalies, num_links = num_links)
#      82         return self.title
#
# ~/Documents/columbia_data_science/capstone/Capstone_KYC/client/articles.py in get_articles_title_all_dates(keyword, dates, num_links)
#     169     :returns a dictionary whose keys are dates (anomalies) and values are lists containing title of articles
#     170     """
# --> 171     return {date: get_articles_title(keyword, date, num_links) for date in dates}
#
# ...

# %%
cl.get_summaries(num_links = 2, k = 1)
# Out:
# Problem with the following url: https://gadgetwise.blogs.nytimes.com/2010/07/27/apple-brings-magic-multitouch-to-the-computer/
# Problem with the following url: https://bits.blogs.nytimes.com/2011/10/27/whats-really-next-for-apple-in-television/
# Problem with the following url: https://bits.blogs.nytimes.com/2013/09/23/apple-sells-nine-million-new-iphones/
# {Timestamp('2007-09-01 00:00:00'): ['(Apple’s market share in music players has not suffered a similar fate, however.)On Wednesday, Apple executives insisted that the price cut had been planned long ago and that the strategy had been conceived in part to keep the iPhone’s pricing in line with its new iPod Touch, a music player that looks like the iPhone but lacks the phone-calling ability.',
#   '5 — Apple announced a price cut for its iPhone today, along with a new iPod that looks like the iPhone and a version of its iTunes store that downloads music directly to the player rather than a computer.'],
# ...

# %%
cl.get_summary(num_links=10, k=2)
# Out:
# Problem with the following url: https://bits.blogs.nytimes.com/2010/01/29/seeing-through-the-avatar-and-apple-hyperbole/
# Problem with the following url: https://bits.blogs.nytimes.com/2010/01/27/reaction-from-the-technology-blogosphere/
# Problem with the following url: https://bits.blogs.nytimes.com/2010/01/27/get-your-non-apple-news/
# Problem with the following url: https://bits.blogs.nytimes.com/2010/01/28/day-two-non-apple-news/
# Problem with the following url: https://gadgetwise.blogs.nytimes.com/2010/07/27/apple-brings-magic-multitouch-to-the-computer/
# Problem with the following url: https://bits.blogs.nytimes.com/2010/07/29/bits-pics-looking-inside-apples-new-trackpad/
# Problem with the following url: https://bits.blogs.nytimes.com/2010/07/16/a-field-trip-to-an-apple-lab/
# Problem with the following url: https://bits.blogs.nytimes.com/2010/07/22/apples-web-browser-allows-sites-to-collect-personal-information/
# ...
