# %%
import sys
sys.path.append("..")
import time
from huginn.huginn import Huginn
from huginn.summarizer import run_summary

# %%
cl = Huginn('Apple')
# Out:
# [{'mid': '/m/0k8z', 'title': 'Apple', 'type': 'Technology company'}, {'mid': '/m/014j1m', 'title': 'Apple', 'type': 'Fruit'}, {'mid': '/g/11c1s04k8p', 'title': 'AirPods', 'type': 'Topic'}, {'mid': '/m/027lnzs', 'title': 'iPhone', 'type': 'Mobile phone'}, {'mid': '/m/01qd72', 'title': 'Apples', 'type': 'Plants'}]
# Enter the mid you are interested in: /m/0k8z

# %%
cl.get_anomalies(k=3)
# Out:
# DatetimeIndex(['2007-09-01', '2010-01-01', '2014-09-01'], dtype='datetime64[ns]', name='date', freq=None)

# %%
cl.plot_interest_with_anomalies()
# Out:
#     If you are not happy with these anomalies, you can call the method 'get_anomalies' and
#     specify the function to get anomalies:
#     - method = 'constant' with parameter k (set to 1 by default)
#     - method = 'rolling' with parameters lookback_mean, lookback_std and k (set to 1, 10, 1 by default)
#     - method = 'ewm' with parameters halflife_mean, halflife_std and k(set to 1,10,1 by default) [default method]

# %%
cl.get_articles_info()
# Out:
# anomaly n°1: 9 articles were found and 100% were retrieved
# anomaly n°2: 7 articles were found and 100% were retrieved
# anomaly n°3: 10 articles were found and 100% were retrieved

# %%
cl.get_articles_info_and_summary_after_LDA(n_components = 2) #default parameter
# Out:
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# {'09-2007': {1: "Apple cuts price of its 8-gigabyte iPhone by $200, to $399. Apple also introduces a new digital music player modeled after its iPhone. Apple struck a wireless music distribution deal with the Starbucks coffee chain. Apple's stock fell more than 5 percent, closing at $136.76.",
#   0: "Averill Farm is high in the rolling Litchfield County hills outside Washington Depot. George Washington didn't sleep here, but he is said to have partied at the original Averill farmhouse. Phoebe DeVos-Cole: “I love to pick apples, and I love to eat them”"},
#  '01-2010': {1: 'Many women say the name evokes awkward associations with feminine hygiene products. Two other high-tech companies already market products called iPad and are laying claim to the trademark. Fujitsu, the Japanese technology firm, may not be quite so eager to forgive and forget.',
#   0: "Apple's A4 chip is crucial to the iPad's speed, reliability and 10-hour battery life. Chip industry experts have yet to put the iPad through their customary rigorous tests. Apple bought its way into the chip business in 2008, acquiring 150-employee start-up PA Semi."},
#  '09-2014': {0: 'Apple says it has received nine complaints about bent iPhone 6 Plus. The company says it performs “rigorous tests throughout the entire development cycle.” Apple says it sold more than 10 million iPhone 6 and 6 Plus in the first three days of release.',
#   1: 'New Apple tool checks iPhones for ‘Kill Switch’ Security. Starting next summer, a new law will require every smartphone sold in California to include a so-called kill switch. With Activation Lock turned on, the device could be unusable without the Apple username and password.'}}

# %%
cl.get_global_summary()
# Out:
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# "Apple cuts price of its 8-gigabyte iPhone by $200, to $399. Apple also introduces a new digital music player modeled after its iPhone. Apple struck a wireless music distribution deal with the Starbucks coffee chain. Apple's stock fell more than 5 percent, closing at $136.76."

# %%
cl.get_summary_of_summaries()
# Out:
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# 'Apple cuts price of its 8-gigabyte iPhone by $200, to $399. Apple also introduces a new digital music player modeled after its iPhone. Apple struck a wireless music distribution deal with the Starbucks coffee chain. Apple says it has received nine complaints about bent iPhone 6 Plus.'
