# %%
import sys
sys.path.append("..")
import time
from huginn.huginn import Huginn

# %%
cl = Huginn('Apple')
# Out:
# [{'mid': '/m/0k8z', 'title': 'Apple', 'type': 'Technology company'}, {'mid': '/m/014j1m', 'title': 'Apple', 'type': 'Fruit'}, {'mid': '/g/11c1s04k8p', 'title': 'AirPods', 'type': 'Topic'}, {'mid': '/m/027lnzs', 'title': 'iPhone', 'type': 'Mobile phone'}, {'mid': '/m/01qd72', 'title': 'Apples', 'type': 'Plants'}]
# Enter the mid you are interested in: /m/0k8z

# %%
cl.plot_interest()

# %%
cl.get_anomalies(k=1)
# Out:
# DatetimeIndex(['2007-09-01', '2008-01-01', '2008-06-01', '2010-01-01',
#                '2010-07-01', '2011-10-01', '2012-09-01', '2013-09-01',
#                '2014-09-01', '2015-03-01'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
cl.plot_interest_with_anomalies()
# Out:
#     If you are not happy with these anomalies, you can call the method 'get_anomalies' and
#     specify the function to get anomalies:
#     - method = 'constant' with parameter k (set to 1 by default)
#     - method = 'rolling' with parameters lookback_mean, lookback_std and k (set to 1, 10, 1 by default)
#     - method = 'ewm' with parameters halflife_mean, halflife_std and k(set to 1,10,1 by default) [default method]

# %%
t1 = time.time()
cl.get_info()
print(str(int(time.time()-t1)) + 's to compute')
# Out:
# anomaly n°1: 9 articles were found and 100% were retrieved
# anomaly n°2: 9 articles were found and 100% were retrieved
# anomaly n°3: 8 articles were found and 100% were retrieved
# anomaly n°4: 7 articles were found and 100% were retrieved
# anomaly n°5: 10 articles were found and 100% were retrieved
# anomaly n°6: 9 articles were found and 100% were retrieved
# anomaly n°7: 10 articles were found and 100% were retrieved
# anomaly n°8: 6 articles were found and 100% were retrieved
# anomaly n°9: 10 articles were found and 100% were retrieved
# anomaly n°10: 9 articles were found and 100% were retrieved
# 24s to compute

# %%
cl.model_lda()

# %%
cl.lda_output
# Out:
# {Timestamp('2007-09-01 00:00:00'): [      Topic0  Topic1  dominant_topic
#   Doc0     1.0     0.0               0
#   Doc1     0.0     1.0               1
#   Doc2     1.0     0.0               0
#   Doc3     1.0     0.0               0
#   Doc4     1.0     0.0               0
#   Doc5     0.0     1.0               1
#   Doc6     0.0     1.0               1
#   Doc7     1.0     0.0               0
#   Doc8     0.0     1.0               1,
#              Num Documents
#   Topic Num
#   0                      5
#   1                      4,
#           Word 0 Word 1  Word 2 Word 3  Word 4   Word 5    Word 6   Word 7  \
#   Topic 0   said  apple     new    nbc   music   itunes     price  averill
#   Topic 1   said  apple  iphone  phone  mobile  process  software   people
#
#            Word 8 Word 9
#   Topic 0  iphone   sell
#   Topic 1    like    new  ],
#  Timestamp('2008-01-01 00:00:00'): [      Topic0  Topic1  dominant_topic
#   Doc0    0.00    1.00               1
#   Doc1    0.00    1.00               1
#   Doc2    1.00    0.00               0
#   Doc3    1.00    0.00               0
#   Doc4    0.00    1.00               1
#   Doc5    1.00    0.00               0
#   Doc6    1.00    0.00               0
#   Doc7    0.00    1.00               1
#   Doc8    0.01    0.99               1,
#              Num Documents
#   Topic Num
#   1                      5
#   0                      4,
#           Word 0    Word 1  Word 2 Word 3      Word 4 Word 5   Word 6  \
#   Topic 0  apple      said   music   jobs     digital  movie   amazon
#   Topic 1  apple  european  itunes   said  commission  music  britain
#
#               Word 7   Word 8   Word 9
#   Topic 0   industry   itunes      new
#   Topic 1  consumers  digital  country  ],
#  Timestamp('2008-06-01 00:00:00'): [      Topic0  Topic1  dominant_topic
#   Doc0    1.00    0.00               0
#   Doc1    0.00    1.00               1
#   Doc2    0.00    1.00               1
#   Doc3    1.00    0.00               0
#   Doc4    0.00    1.00               1
#   Doc5    0.00    1.00               1
#   Doc6    0.99    0.01               0
#   Doc7    1.00    0.00               0,
#              Num Documents
#   Topic Num
#   1                      4
#   0                      4,
#             Word 0 Word 1 Word 2    Word 3 Word 4     Word 5 Word 6 Word 7  \
#   Topic 0   iphone   said  intel      chip    arm      apple    new  power
#   Topic 1  windows  pixar   jobs  computer    new  microsoft  price    web
#
#           Word 8    Word 9
#   Topic 0  phone     women
#   Topic 1  apple  software  ],
#  Timestamp('2010-01-01 00:00:00'): [      Topic0  Topic1  dominant_topic
#   Doc0    0.00    1.00               1
#   Doc1    0.00    1.00               1
#   Doc2    1.00    0.00               0
#   Doc3    1.00    0.00               0
#   Doc4    1.00    0.00               0
#   Doc5    0.00    1.00               1
#   Doc6    0.01    0.99               1,
#              Num Documents
#   Topic Num
#   1                      4
#   0                      3,
#           Word 0  Word 1 Word 2      Word 3   Word 4 Word 5   Word 6 Word 7  \
#   Topic 0   ipad  device  apple  technology  writers  going     like  cisco
#   Topic 1  apple    chip    new     company     said   ipad  product  chips
#
#               Word 8        Word 9
#   Topic 0  trademark  announcement
#   Topic 1    quarter        online  ],
#  Timestamp('2010-07-01 00:00:00'): [      Topic0  Topic1  dominant_topic
#   Doc0    1.00    0.00               0
#   Doc1    0.99    0.01               0
#   Doc2    0.00    1.00               1
#   Doc3    1.00    0.00               0
#   Doc4    0.00    1.00               1
#   Doc5    0.00    1.00               1
#   Doc6    0.00    1.00               1
#   Doc7    0.00    1.00               1
#   Doc8    0.01    0.99               1
#   Doc9    0.00    1.00               1,
#              Num Documents
#   Topic Num
#   1                      7
#   0                      3,
#           Word 0 Word 1  Word 2    Word 3 Word 4 Word 5   Word 6    Word 7  \
#   Topic 0  apple   said  iphone  trackpad   ipad  magic  percent   company
#   Topic 1  apple   said  iphone   antenna  phone   jobs  company  software
#
#              Word 8  Word 9
#   Topic 0   quarter   sales
#   Topic 1  problems  phones  ],
#  Timestamp('2011-10-01 00:00:00'): [      Topic0  Topic1  dominant_topic
#   Doc0    0.00    1.00               1
#   Doc1    1.00    0.00               0
#   Doc2    0.01    0.99               1
#   Doc3    0.01    0.99               1
#   Doc4    0.77    0.23               0
#   Doc5    0.99    0.01               0
#   Doc6    0.00    1.00               1
#   Doc7    0.00    1.00               1
#   Doc8    0.00    1.00               1,
#              Num Documents
#   Topic Num
#   1                      6
#   0                      3,
#           Word 0    Word 1 Word 2   Word 3 Word 4      Word 5  Word 6 Word 7  \
#   Topic 0   jobs  isaacson  apple    steve   book        like   event   time
#   Topic 1  apple    iphone   said  company   ipad  television  icloud   jobs
#
#           Word 8 Word 9
#   Topic 0   said   does
#   Topic 1    new   year  ],
#  Timestamp('2012-09-01 00:00:00'): [      Topic0  Topic1  dominant_topic
#   Doc0     1.0     0.0               0
#   Doc1     1.0     0.0               0
#   Doc2     0.0     1.0               1
#   Doc3     1.0     0.0               0
#   Doc4     1.0     0.0               0
#   Doc5     0.0     1.0               1
#   Doc6     0.0     1.0               1
#   Doc7     1.0     0.0               0
#   Doc8     1.0     0.0               0
#   Doc9     1.0     0.0               0,
#              Num Documents
#   Topic Num
#   0                      7
#   1                      3,
#           Word 0 Word 1  Word 2 Word 3   Word 4  Word 5    Word 6      Word 7  \
#   Topic 0  apple   maps  google   said      app  iphone       new         map
#   Topic 1  apple   maps  iphone    new  company    said  mapquest  navigation
#
#             Word 8      Word 9
#   Topic 0  company        like
#   Topic 1    nokia  smartphone  ],
#  Timestamp('2013-09-01 00:00:00'): [      Topic0  Topic1  dominant_topic
#   Doc0     1.0     0.0               0
#   Doc1     1.0     0.0               0
#   Doc2     0.0     1.0               1
#   Doc3     0.0     1.0               1
#   Doc4     0.0     1.0               1
#   Doc5     0.0     1.0               1,
#              Num Documents
#   Topic Num
#   1                      4
#   0                      2,
#           Word 0 Word 1  Word 2  Word 3 Word 4 Word 5     Word 6   Word 7  \
#   Topic 0  apple  brand  brands    year   cola   coca  executive     said
#   Topic 1  apple    new     ios  iphone    app  phone    million  twitter
#
#             Word 8  Word 9
#   Topic 0   report  global
#   Topic 1  iphones   flash  ],
#  Timestamp('2014-09-01 00:00:00'): [      Topic0  Topic1  dominant_topic
#   Doc0    1.00    0.00               0
#   Doc1    1.00    0.00               0
#   Doc2    1.00    0.00               0
#   Doc3    0.00    1.00               1
#   Doc4    0.00    1.00               1
#   Doc5    1.00    0.00               0
#   Doc6    1.00    0.00               0
#   Doc7    1.00    0.00               0
#   Doc8    1.00    0.00               0
#   Doc9    0.01    0.99               1,
#              Num Documents
#   Topic Num
#   0                      7
#   1                      3,
#           Word 0  Word 1  Word 2 Word 3 Word 4   Word 5  Word 6   Word 7  \
#   Topic 0  apple  iphone    said  phone    tax  company   watch   people
#   Topic 1  apple    said  paypal  china    pay   market  phones  iphones
#
#             Word 8   Word 9
#   Topic 0   apples  ireland
#   Topic 1  payment      new  ],
#  Timestamp('2015-03-01 00:00:00'): [      Topic0  Topic1  dominant_topic
#   Doc0    0.00    1.00               1
#   Doc1    1.00    0.00               0
#   Doc2    1.00    0.00               0
#   Doc3    0.00    1.00               1
#   Doc4    1.00    0.00               0
#   Doc5    1.00    0.00               0
#   Doc6    1.00    0.00               0
#   Doc7    1.00    0.00               0
#   Doc8    0.99    0.01               0,
#              Num Documents
#   Topic Num
#   0                      7
#   1                      2,
#           Word 0 Word 1 Word 2     Word 3   Word 4   Word 5 Word 6 Word 7  \
#   Topic 0  apple   jobs   said      steve     book  company    pay    new
#   Topic 1  apple   jobs  music  streaming  service    beats   cook    new
#
#           Word 8     Word 9
#   Topic 0  banks     credit
#   Topic 1  steve  schlender  ]}
