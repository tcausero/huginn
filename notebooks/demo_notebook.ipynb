# %%
import sys
sys.path.append("..")
import time
from client.demo_console import demo_console

# %%
cl = demo_console()
# Out:
# keyword: Facebook
# [{'mid': '/m/02y1vz', 'title': 'Facebook', 'type': 'Social networking service'}, {'mid': '/m/0hmyfsv', 'title': 'Facebook, Inc.', 'type': 'Company'}, {'mid': '/m/0k2ljgx', 'title': 'Facebook Messenger', 'type': 'Topic'}, {'mid': '/m/0crj9_l', 'title': 'Face book', 'type': 'Topic'}, {'mid': '/g/11c5h24bx2', 'title': 'Facebook', 'type': 'Topic'}]
# Enter the mid you are interested in: /m/02y1vz

# %%
cl.plot_interest()

# %%
cl.get_anomalies()
# Out:
# DatetimeIndex(['2007-09-01', '2007-10-01', '2008-04-01', '2008-05-01',
#                '2008-10-01', '2008-11-01', '2008-12-01', '2009-09-01',
#                '2012-05-01', '2014-04-01'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
cl.plot_interest_with_anomalies()
# Out:
#         If you are not happy with these anomalies, you can call the method 'get_anomalies' and
#         specify the function to get anomalies:
#         - method = 'constant' with parameter k (set to 1 by default)
#         - method = 'rolling' with parameters lookback_mean, lookback_std and k (set to 1, 10, 1 by default)
#         - method = 'ewm' with parameters halflife_mean, halflife_std and k(set to 1,10,1 by default) [default method]

# %%
num_links = 10
k = 2

# %%
t1 = time.time()
cl.get_summary(num_links = num_links, k = k)
print(str(int(time.time()-t1)) + 's to compute')
# Out:
# Problem with the following url: https://ideas.blogs.nytimes.com/2008/10/29/egyptian-facebook-activism/
# Problem with the following url: https://pogue.blogs.nytimes.com/2008/09/09/why-does-facebook-do-that/
# Problem with the following url: https://pogue.blogs.nytimes.com/2008/09/09/blogs/09pogue-why-does538.html
# Problem with the following url: https://themedium.blogs.nytimes.com/2008/09/12/in-this-weeks-magazine-facebook-politics/
# Problem with the following url: https://dealbook.nytimes.com/2012/05/31/facebook-shares-extend-their-slide/
# Problem with the following url: https://dealbook.nytimes.com/2012/05/29/liking-linkedin-while-wary-of-facebook/
# Problem with the following url: https://dealbook.nytimes.com/2012/05/24/been-facebook-ed-lately/
# Problem with the following url: https://gadgetwise.blogs.nytimes.com/2012/05/29/qa-finding-missing-facebook-updates/
# Problem with the following url: https://bits.blogs.nytimes.com/2014/04/18/digital-diary-facebooks-existential-crisis/
# Problem with the following url: https://bits.blogs.nytimes.com/2014/05/01/daily-report-facebook-to-enhance-privacy-controls/
# Problem with the following url: https://bits.blogs.nytimes.com/2014/04/17/twitter-goes-after-a-facebook-cash-cow/
# Problem with the following url: https://bits.blogs.nytimes.com/2014/04/15/facebook-forces-users-to-install-separate-messaging-app/
# Problem with the following url: https://bits.blogs.nytimes.com/2014/04/16/can-facebook-innovate-a-conversation-with-mark-zuckerberg/
# Problem with the following url: https://bits.blogs.nytimes.com/2014/04/17/facebooks-new-twist-on-location-sharing-puts-users-in-control/
# 148s to compute

# %%
print(dir(cl))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'anomalies', 'check_got_anomalies', 'get_anomalies', 'get_summaries', 'get_summary', 'get_title_text', 'interest', 'mid', 'name', 'plot_interest', 'plot_interest_with_anomalies', 'summaries', 'summary', 'text', 'title']

# %%
cl.summary
# Out:
# {Timestamp('2007-09-01 00:00:00'): '“The custom of protecting freedom of speech allows people to address belief systems in the harshest of terms,” he wrote, adding that his group’s sentiment is “a peaceful one; atheism is a belief system that few will die for, because there is no reward.” He noted that a search on Facebook finds a multitude of sites attacking him personally, “which qualifies as hate speech,” unlike his site, “which concerns itself with abstract ideas.” One of the officers of the petition-drive group, Essma Bargewee, who said in an e-mail message that she is 20 years old and studying business at Montclair State University in New Jersey, said she joined and invited some friends and posted at a few other groups in Facebook.',
#  Timestamp('2007-10-01 00:00:00'): 'When the fledgling company first expanded beyond its roots at Harvard to include Yale, he said, “The people at Harvard complained about it and said, ‘Hey, this used to be just for us!’” The fretting subsides each time, he said, “as soon as they go back to using the program and realize this hasn’t done anything to deteriorate their experience.” FOR the most part, in fact, the entry of millions of people with, you know, jobs and stuff, has been greeted with an epic “whatever,” said Clay Shirky, an adjunct professor in New York University’s interactive telecommunications program.',
#  Timestamp('2008-04-01 00:00:00'): ' In studies involving Internet telephone directories, Social Security death index records and clinical experiments, Brett Pelham, a social psychologist, and colleagues have found in the past six years that Johnsons are more likely to wed Johnsons, women named Virginia are more likely to live in (and move to) Virginia, and people whose surname is Lane tend to have addresses that include the word “lane,” not “street.”During the 2000 presidential campaign, people whose surnames began with B were more likely to contribute to George Bush, while those whose surnames began with G were more likely to contribute to Al Gore.',
#  Timestamp('2008-05-01 00:00:00'): 'I asked him once, ‘You do everything right and yet you’re listening to music?’ He said, ‘I know music is haram, and inshallah, with time I will be able to stop listening to music too.’\xa0” Haram means forbidden, and inshallah means “God willing.” She added, “I told him, ‘I want a husband like you.’\xa0”Separated From Cousins Shaden lives in a large walled compound in a prosperous Riyadh suburb; her father’s brothers live with their families in separate houses within the compound, and the families share a common garden and pool..',
#  Timestamp('2008-10-01 00:00:00'): '“You know that old cartoon? ‘On the Internet, nobody knows you’re a dog’? On the Internet today, everybody knows you’re a dog! If you don’t want people to know you’re a dog, you’d better stay away from a keyboard.” Or, as Leisa Reichelt, a consultant in London who writes regularly about ambient tools, put it to me: “Can you imagine a Facebook for children in kindergarten, and they never lose touch with those kids for the rest of their lives? What’s that going to do to them?” Young people today are already developing an attitude toward their privacy that is simultaneously vigilant and laissez-faire..',
#  Timestamp('2008-11-01 00:00:00'): 'Ed Morrissey, a conservative blogger at Hot Air, posted the text (you can find it at nytimes.com/publiceditorsjournal) and said it was “an attempt by a gossip-rag muckraker to get teenagers to dish dirt on a celebrity.” Kantor said she was glad the text became public, so that people could see it was a neutrally worded effort to get information, primarily adult sources, not “digging for dirt.” Times editors said they wished that Kantor had consulted with them before contacting the teens.',
#  Timestamp('2008-12-01 00:00:00'): 'Ed Morrissey, a conservative blogger at Hot Air, posted the text (you can find it at nytimes.com/publiceditorsjournal) and said it was “an attempt by a gossip-rag muckraker to get teenagers to dish dirt on a celebrity.” Kantor said she was glad the text became public, so that people could see it was a neutrally worded effort to get information, primarily adult sources, not “digging for dirt.” Times editors said they wished that Kantor had consulted with them before contacting the teens.',
#  Timestamp('2009-09-01 00:00:00'): 'Julie Klam, a writer and prolific and eloquent Facebook updater, said in her own e-mail message, “I have noticed the exodus, and I kind of feel like it’s kids getting tired of a new toy.” Klam, who still posts updates to Facebook but now prefers Twitter for professional networking, added, “Facebook is good for finding people, but by now the novelty of that has worn off, and everyone’s been found.” As of a few months ago, she told me, Facebook “felt dead.” Is Facebook doomed to someday become an online ghost town, run by zombie users who never update their pages and packs of marketers picking at the corpses of social circles they once hoped to exploit? Sad, if so.',
#  Timestamp('2012-05-01 00:00:00'): '“People were able to send their kids to college or buy a second home or retire early or take care of their parents or people who were ailing, or they became more philanthropic.” It’s because of true stories like this — and not the ones you never hear, about people who gave up on Home Depot stock during a stagnant stretch during the 1980s or bought it while it bounced around over the last decade or so — that people will keep trying.',
#  Timestamp('2014-04-01 00:00:00'): '“One of the things that we’re trying to do with Creative Labs and all our experiences is explore things that aren’t all tied to Facebook identity.” If the new plan succeeds, then, one day large swaths of Facebook may not look like Facebook — and may not even bear the name Facebook.'}
