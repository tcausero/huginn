# %%
import sys
sys.path.append("..")
import time
from huginn.huginn import Huginn

# %%
cl = Huginn('Uber')
# Out:
# [{'mid': '/g/11ckq_1t0s', 'title': 'Uber Eats', 'type': 'Online food ordering company'}, {'mid': '/m/0gx0wlr', 'title': 'Uber Technologies Inc', 'type': 'Ridesharing company'}, {'mid': '/m/02wkdb', 'title': 'Uberlândia', 'type': 'Municipality in Brazil'}, {'mid': '/m/06r7yq', 'title': 'Uberaba', 'type': 'Municipality in Brazil'}, {'mid': '/g/11b5wl8w0q', 'title': 'Uber HQ', 'type': 'Topic'}]
# Enter the mid you are interested in: /m/0gx0wlr

# %%
cl.get_anomalies(k = 3)
cl.plot_interest_with_anomalies()
# Out:
#     If you are not happy with these anomalies, you can call the method 'get_anomalies' and
#     specify the function to get anomalies:
#     - method = 'constant' with parameter k (set to 1 by default)
#     - method = 'rolling' with parameters lookback_mean, lookback_std and k (set to 1, 10, 1 by default)
#     - method = 'ewm' with parameters halflife_mean, halflife_std and k(set to 1,10,1 by default) [default method]

# %%
cl.get_articles_info()
# Out:
# anomaly n°1: 9 articles were found and 100% were retrieved
# anomaly n°2: 10 articles were found and 100% were retrieved
# anomaly n°3: 10 articles were found and 100% were retrieved

# %%
cl.get_local_summaries()
# Out:
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# {'01-2014': {0: "Sofia Liu, 6, was hit by an Uber driver waiting for a fare on New Year's Eve. The driver, Syed Muzaffar, had been driving for Uber about a month, his lawyer said. In the new sharing economy, he takes the fall, the suit says.",
#   1: 'Handybook buys Exec, a San Francisco start-up that lets people book house cleaners. Exec originally started as an errand service, competing with the likes of TaskRabbit. Handybook is based in New York, and has struggled to gain a foothold in Silicon Valley.'},
#  '06-2014': {0: 'Blade, a Helicopter-Booking App, to Partner With Uber. Blade lets users order helicopter rides to the Hamptons and Montauk. Uber is already testing out services, like a courier service in New York. If the test goes well, Uber suggests, the chopper rides may become a permanent feature.',
#   1: "London Transport Regulator says Uber can legally operate in the British capital. Decision by Transport for London centered on the technology that powers the start-up's service. Under London’s taxi rules, only licensed black taxis can use meters in their vehicles."},
#  '12-2014': {0: 'Uber suspends its operations in Spain late Tuesday. The decision came in response to a judge’s ruling this month. The judge also ordered that Spanish telecommunications operators and banks stop supporting the company. The latest setback for Uber follows a series of legal problems around the world.',
#   1: 'Uber customers use the smartphone app to summon a taxi in New York City. The company on Wednesday said that it would begin charging a $2 “booking fee” for customers. The service, which is called UberT, is what transportation companies call an “e-hailing” feature.'}}

# %%
cl.get_global_summary()
# Out:
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# "Sofia Liu, 6, was hit by an Uber driver waiting for a fare on New Year's Eve. The driver, Syed Muzaffar, had been driving for Uber about a month, his lawyer said. In the new sharing economy, he takes the fall, the suit says."

# %%
cl.get_summary_of_summaries()
# Out:
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.
# 'Handybook buys Exec, a San Francisco start-up that lets people book house cleaners. Blade lets users order helicopter rides to the Hamptons and Montauk. If the test goes well, Uber suggests, the chopper rides may become a permanent feature.'
