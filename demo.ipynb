# %%
from interest import get_keyword, get_interest
from anomalies import get_anomalies_v1, get_anomalies_v2, get_anomalies_v3
from plot_data import plot_data, plot_data_with_anomalies

# %%
keyword = get_keyword()
data = get_interest(keyword)
plot_data(data)
# Out:
# keyword: Point72
# [{'mid': '/m/06bqwq', 'title': 'Point72 Asset Management', 'type': 'Hedge fund company'}]
# Enter the mid you are interested in: /m/06bqwq

# %%
get_anomalies_v1(data)
# Out:
# DatetimeIndex(['2009-06-01', '2009-07-01', '2013-02-01', '2013-03-01',
#                '2018-03-01', '2018-04-01', '2019-01-01', '2019-06-01',
#                '2019-09-01', '2019-12-01'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
get_anomalies_v2(data, lookback = 10)
# Out:
# DatetimeIndex(['2009-06-01', '2009-07-01', '2011-03-01', '2012-12-01',
#                '2013-02-01', '2013-03-01', '2014-04-01', '2018-03-01',
#                '2019-06-01', '2019-12-01'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
get_anomalies_v3(data, 10)
# Out:
# DatetimeIndex(['2009-06-01', '2009-07-01', '2011-03-01', '2012-12-01',
#                '2013-02-01', '2013-03-01', '2018-03-01', '2019-01-01',
#                '2019-06-01', '2019-12-01'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
plot_data_with_anomalies(data, get_anomalies_v3(data, 5))
