# %%
from interest import get_keyword, get_interest
from anomalies import get_anomalies_v1, get_anomalies_v2, get_anomalies_v3
from plot_data import plot_data, plot_data_with_anomalies
from articles import get_articles_text_all_dates, get_articles_title_all_dates

# %%
keyword = get_keyword()
data = get_interest(keyword)
plot_data(data)
# Out:
# keyword: Point72
# [{'mid': '/m/06bqwq', 'title': 'Point72 Asset Management', 'type': 'Hedge fund company'}]
# Enter the mid you are interested in: /m/06bqwq

# %%
date_anomalies = get_anomalies_v3(data, 2, 4)

# %%
plot_data_with_anomalies(data, date_anomalies)

# %%
get_articles_title_all_dates(keyword, date_anomalies, num_links = 5)
# Out:
# Problem with the following url: https://mediadecoder.blogs.nytimes.com/2009/05/27/jon-kate-are-a-business-at-this-point-magazine-editor-says/
# Problem with the following url: https://london2012.blogs.nytimes.com/2012/08/10/live-coverage-of-u-s-argentina-mens-basketball-semifinal/
# Problem with the following url: https://offthedribble.blogs.nytimes.com/2013/01/16/keeping-score-magic-pay-less-attention-to-the-3-point-line/
# Problem with the following url: https://thequad.blogs.nytimes.com/2013/01/11/butlers-next-challenge-the-atlantic-10/
# Problem with the following url: https://offthedribble.blogs.nytimes.com/2013/02/14/best-dunk-and-3-point-specialists-no-contest/
# Problem with the following url: https://offthedribble.blogs.nytimes.com/2013/02/22/for-kyrie-irving-a-milestone-week/
# Problem with the following url: https://dealbook.nytimes.com/2014/03/13/s-e-c-brings-case-against-10th-former-sac-capital-employee/
# ...

# %%
get_articles_text_all_dates(keyword, date_anomalies, num_links=2)
# Out:
# Problem with the following url: https://artsbeat.blogs.nytimes.com/2010/11/29/critics-picks-video-point-blank/
# Problem with the following url: https://opinionator.blogs.nytimes.com/2012/08/06/the-point-of-exclamation/
# Problem with the following url: https://offthedribble.blogs.nytimes.com/2013/01/16/keeping-score-magic-pay-less-attention-to-the-3-point-line/
# Problem with the following url: https://offthedribble.blogs.nytimes.com/2013/02/14/best-dunk-and-3-point-specialists-no-contest/
# Problem with the following url: https://goal.blogs.nytimes.com/2013/02/03/reina-gives-city-a-point-but-not-much-hope/
# Problem with the following url: https://dealbook.nytimes.com/2014/03/31/drug-company-seeks-to-be-repaid-legal-fees-in-sac-capital-inquiry/
# Problem with the following url: https://dealbook.nytimes.com/2014/03/17/two-sac-capital-traders-jump-to-highbridge-capital/
# ...
