# %%
from client import client
keyword = 'Point72'
mid = '/m/06bqwq'
cl = client(keyword, mid)

# %%
cl.get_anomalies("ewm", halflife_std = 3)
# Out:
# DatetimeIndex(['2008-06-01', '2011-08-01', '2012-06-01', '2013-02-01',
#                '2013-03-01', '2017-02-01', '2017-03-01', '2018-09-01',
#                '2019-12-01', '2020-03-01'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
cl.plot_interest_with_anomalies()
# Out:
#         If you are not happy with these anomalies, you can call the method 'get_anomalies' and
#         specify the function to get anomalies:
#         - constant mean and std
#         - rolling mean and std (parameter lookback set to 1 and 10)
#         - ewm mean and std (parameter halflife set to 1 and 10) [default method]

# %%
cl.get_title(num_links=1)
# Out:
# {Timestamp('2007-09-01 00:00:00'): ['Obama’s Plan to Restore New Orleans'],
#  Timestamp('2008-01-01 00:00:00'): ['Obama Aide Ties Pakistan to Iraq War'],
#  Timestamp('2008-02-01 00:00:00'): ['Obama Donates Challenged Funds']}

# %%
cl.get_text()
# Out:
# Problem with the following url: https://artsbeat.blogs.nytimes.com/2010/11/29/critics-picks-video-point-blank/
# Problem with the following url: https://offthedribble.blogs.nytimes.com/2013/01/16/keeping-score-magic-pay-less-attention-to-the-3-point-line/
# ...

# %%
from demo_console import demo_console
demo_console()
# Out:
# keyword: Point72
# [{'mid': '/m/06bqwq', 'title': 'Point72 Asset Management', 'type': 'Hedge fund company'}]
# Enter the mid you are interested in: /m/06bqwq
